# %%
import pandas as pd
import json

json_data_path = "C:/Users/Rajasekar/Downloads/fashion_products_dataset.json"

# Read JSON file into DataFrame
df = pd.read_json(json_data_path)

# Display the DataFrame
df
# Out:
# C:\Users\Rajasekar\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                                         _id actual_price average_rating brand  \
# 0      fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2,999            3.9  York
# 1      893e6980-f2a0-531f-b056-34dd63fe912c        1,499            3.9  York
# 2      eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2,999            3.9  York
# 3      3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2,999            3.9  York
# 4      750caa3d-6264-53ca-8ce1-94118a1d8951        2,999            3.9  York
# ...                                     ...          ...            ...   ...
# 29995  3705c6bd-6f23-529a-9b64-15b8fc568efa        2,299                  Oka
# 29996  f2a683e4-634d-5a11-8950-2d56b924576d          799            3.8   Oka
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              30000 non-null  object
#  1   actual_price     30000 non-null  object
#  2   average_rating   30000 non-null  object
#  3   brand            30000 non-null  object
#  4   category         30000 non-null  object
#  5   crawled_at       30000 non-null  datetime64[ns]
#  6   description      30000 non-null  object
#  7   discount         30000 non-null  object
#  8   images           30000 non-null  object
#  9   out_of_stock     30000 non-null  bool
#  10  pid              30000 non-null  object
#  11  product_details  30000 non-null  object
#  12  seller           30000 non-null  object
#  13  selling_price    30000 non-null  object
#  14  sub_category     30000 non-null  object
#  15  title            30000 non-null  object
# ...

# %%
df.tail()
# Out:
#                                         _id actual_price average_rating brand  \
# 29995  3705c6bd-6f23-529a-9b64-15b8fc568efa        2,299                  Oka
# 29996  f2a683e4-634d-5a11-8950-2d56b924576d          799            3.8   Oka
# 29997  1efa858c-1360-59a6-9624-bb04eddb492c        4,999                  Oka
# 29998  9fdfdd22-487b-599b-8be6-5dd00eb987c5        3,125            3.8   Oka
# 29999  a5396fab-753c-5cd7-bad9-050964f95a0f        3,125                  Oka
#
#                        category          crawled_at  \
# 29995  Clothing and Accessories 2021-02-11 01:31:54
# 29996  Clothing and Accessories 2021-02-11 01:31:54
# 29997  Clothing and Accessories 2021-02-11 01:31:54
# 29998  Clothing and Accessories 2021-02-11 01:31:55
# 29999  Clothing and Accessories 2021-02-11 01:31:55
#
#                                              description discount  \
# 29995                                                     40% off
# ...

# %%
# Save the DataFrame to a CSV file
df.to_csv("predifined.csv", index=False)

# %%
import pandas as pd
df1=pd.read_csv('C:/Users/Rajasekar/Downloads/predifined.csv')
df1
# Out:
#                                         _id actual_price  average_rating  \
# 0      fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2,999             3.9
# 1      893e6980-f2a0-531f-b056-34dd63fe912c        1,499             3.9
# 2      eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2,999             3.9
# 3      3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2,999             3.9
# 4      750caa3d-6264-53ca-8ce1-94118a1d8951        2,999             3.9
# ...                                     ...          ...             ...
# 29995  3705c6bd-6f23-529a-9b64-15b8fc568efa        2,299             NaN
# 29996  f2a683e4-634d-5a11-8950-2d56b924576d          799             3.8
# 29997  1efa858c-1360-59a6-9624-bb04eddb492c        4,999             NaN
# 29998  9fdfdd22-487b-599b-8be6-5dd00eb987c5        3,125             3.8
# 29999  a5396fab-753c-5cd7-bad9-050964f95a0f        3,125             NaN
#
#       brand                  category           crawled_at  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              30000 non-null  object
#  1   actual_price     29137 non-null  object
#  2   average_rating   27554 non-null  float64
#  3   brand            27932 non-null  object
#  4   category         30000 non-null  object
#  5   crawled_at       30000 non-null  object
#  6   description      18017 non-null  object
#  7   discount         29059 non-null  object
#  8   images           30000 non-null  object
#  9   out_of_stock     30000 non-null  bool
#  10  pid              30000 non-null  object
#  11  product_details  30000 non-null  object
#  12  seller           28259 non-null  object
#  13  selling_price    29998 non-null  object
#  14  sub_category     30000 non-null  object
#  15  title            30000 non-null  object
# ...

# %%
df1['brand'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Rajasekar\AppData\Local\Temp\ipykernel_34920\696969028.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['brand'].fillna(method='ffill', inplace=True)
# C:\Users\Rajasekar\AppData\Local\Temp\ipykernel_34920\696969028.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1['brand'].fillna(method='ffill', inplace=True)

# %%
mean_rating = df1['average_rating'].mean()
df1['average_rating'].fillna(mean_rating, inplace=True)
# Out:
# C:\Users\Rajasekar\AppData\Local\Temp\ipykernel_34920\1686073676.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['average_rating'].fillna(mean_rating, inplace=True)

# %%
# Remove commas and convert to numeric
df1['actual_price'] = df1['actual_price'].str.replace(',', '').astype('float')
mean_actual_price = df1['actual_price'].mean()
df1['actual_price'].fillna(mean_actual_price, inplace=True)
# Out:
# C:\Users\Rajasekar\AppData\Local\Temp\ipykernel_34920\1719313002.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['actual_price'].fillna(mean_actual_price, inplace=True)

# %%
# Extract numeric part and convert to numeric
df1['discount'] = pd.to_numeric(df1['discount'].str.extract('(\d+)', expand=False), errors='coerce')

# %%
df1.dropna(subset=['discount'], inplace=True)

# %%
df1['seller'].fillna(method='bfill', inplace=True)
# Out:
# C:\Users\Rajasekar\AppData\Local\Temp\ipykernel_34920\3173623883.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['seller'].fillna(method='bfill', inplace=True)
# C:\Users\Rajasekar\AppData\Local\Temp\ipykernel_34920\3173623883.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1['seller'].fillna(method='bfill', inplace=True)

# %%
df1['seller'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Rajasekar\AppData\Local\Temp\ipykernel_34920\1326835728.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1['seller'].fillna(method='ffill', inplace=True)

# %%
df1
# Out:
#                                         _id  actual_price  average_rating  \
# 0      fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2999.0        3.900000
# 1      893e6980-f2a0-531f-b056-34dd63fe912c        1499.0        3.900000
# 2      eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2999.0        3.900000
# 3      3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2999.0        3.900000
# 4      750caa3d-6264-53ca-8ce1-94118a1d8951        2999.0        3.900000
# ...                                     ...           ...             ...
# 29995  3705c6bd-6f23-529a-9b64-15b8fc568efa        2299.0        3.641972
# 29996  f2a683e4-634d-5a11-8950-2d56b924576d         799.0        3.800000
# 29997  1efa858c-1360-59a6-9624-bb04eddb492c        4999.0        3.641972
# 29998  9fdfdd22-487b-599b-8be6-5dd00eb987c5        3125.0        3.800000
# 29999  a5396fab-753c-5cd7-bad9-050964f95a0f        3125.0        3.641972
#
#       brand                  category           crawled_at  \
# ...

# %%
df1.drop(columns=['description'], inplace=True)

# %%
df1['selling_price'] = df1['selling_price'].str.replace(',', '').astype('int')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29059 entries, 0 to 29999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              29059 non-null  object
#  1   actual_price     29059 non-null  float64
#  2   average_rating   29059 non-null  float64
#  3   brand            29059 non-null  object
#  4   category         29059 non-null  object
#  5   crawled_at       29059 non-null  object
#  6   discount         29059 non-null  float64
#  7   images           29059 non-null  object
#  8   out_of_stock     29059 non-null  bool
#  9   pid              29059 non-null  object
#  10  product_details  29059 non-null  object
#  11  seller           29059 non-null  object
#  12  selling_price    29059 non-null  int32
#  13  sub_category     29059 non-null  object
#  14  title            29059 non-null  object
#  15  url              29059 non-null  object
# ...

# %%
df1.describe()
# Out:
#        actual_price  average_rating      discount  selling_price
# count  29059.000000    29059.000000  29059.000000   29059.000000
# mean    1471.168795        3.641361     50.336109     702.724010
# std      959.493535        0.639152     16.823987     542.677335
# min      150.000000        1.000000      1.000000      99.000000
# 25%      869.000000        3.300000     40.000000     390.000000
# 50%     1249.000000        3.700000     53.000000     538.000000
# 75%     1799.000000        4.000000     63.000000     824.000000
# max    12999.000000        5.000000     87.000000    7999.000000

# %%
# Univariate Analysis:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df1['actual_price'], bins=20, kde=True)
plt.show()
# Out:
# C:\Users\Rajasekar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Distribution of Categorical Variables:
sns.countplot(x='category', data=df1)
plt.xticks(rotation=45)
plt.show()

# %%
#Visualize relationships between two numeric variables using scatter plots.:
sns.scatterplot(x='actual_price', y='selling_price', data=df1)
plt.show()

# %%
The scatter plot shows a positive correlation between the actual price and the selling price. This means that as the actual price increases, the selling price also tends to increase.

# %%
sns.barplot(x='category', y='actual_price', data=df1)
plt.xticks(rotation=45)
plt.show()

# %%
#Multivariate Analysis:
#Visualize relationships between multiple numeric variables using pair plots
sns.pairplot(df1[['actual_price', 'selling_price', 'discount', 'average_rating']])
plt.show()
# Out:
# C:\Users\Rajasekar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rajasekar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rajasekar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#Relationships between two categorical variables
pd.crosstab(df1['category'], df1['out_of_stock']).plot(kind='bar', stacked=True)
plt.show()

# %%
plt.figure(figsize=(14, 8))  # Adjust the figure size if needed
top_brands = df1['brand'].value_counts().head(30)  # Select the top 30 brands
sns.countplot(x='brand', data=df1, order=top_brands.index)
plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels for better visibility
plt.title('Top 30 Brands - Distribution of Brand')
plt.show()

# %%
#Analyzing pricing trends and discount strategies
price_stats = df1['actual_price'].describe()

# Display the statistics
print(price_stats)
# Out:
# count    29059.000000
# mean      1471.168795
# std        959.493535
# min        150.000000
# 25%        869.000000
# 50%       1249.000000
# 75%       1799.000000
# max      12999.000000
# Name: actual_price, dtype: float64

# %%
#Visualize the Distribution of Prices
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of Actual Prices
plt.figure(figsize=(10, 6))
sns.histplot(df1['actual_price'], bins=30, kde=True)
plt.title('Distribution of Actual Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Rajasekar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Correlation Between Discounts and Sellingprice:
plt.figure(figsize=(10, 6))
sns.scatterplot(x='discount', y='selling_price', data=df1)
plt.title('Scatter Plot of Discounts vs. Selling Prices')
plt.xlabel('Discount')
plt.ylabel('Selling Price')
plt.show()

# %%
#Correlation Between Discounts and Sales:
plt.figure(figsize=(10, 6))
sns.scatterplot(x='discount', y='actual_price', data=df1)
plt.title('Scatter Plot of Discounts vs. Selling Prices')
plt.xlabel('Discount')
plt.ylabel('Selling Price')
plt.show()

# %%
# Correlation Heatmap
correlation_matrix = df1[['actual_price', 'selling_price', 'discount']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#Top-Performing Sellers:
seller_counts = df1['seller'].value_counts()

top_sellers = seller_counts.head(10)

print(top_sellers)
# Out:
# seller
# RetailNet                1723
# ARBOR                     999
# SandSMarketing            993
# BioworldMerchandising     867
# Keoti                     668
# AFFGARMENTS               623
# Black Beatle              560
# Tayab Manch Fashions      542
# PixFab                    527
# ArvindTrueBlue            512
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar plot of the number of products sold by each seller
plt.figure(figsize=(12, 6))
sns.barplot(x=top_sellers.index, y=top_sellers.values)
plt.xticks(rotation=45)
plt.title('Top 10 Sellers - Number of Products Sold')
plt.xlabel('Seller')
plt.ylabel('Number of Products Sold')
plt.show()

# %%
# Select the top 20 sellers for visualization
top_sellers = df1['seller'].value_counts().head(20).index

# Filter data for top sellers
top_sellers_data = df1[df1['seller'].isin(top_sellers)]

# Scatter plot of Discounts vs. Selling Prices for Top 20 Sellers
plt.figure(figsize=(12, 8))
sns.scatterplot(x='discount', y='selling_price', hue='seller', data=top_sellers_data, palette='viridis', s=100)
plt.title('Scatter Plot of Discounts vs. Selling Prices for Top 20 Sellers')
plt.xlabel('Discount')
plt.ylabel('Selling Price')
plt.legend(title='Seller', bbox_to_anchor=(1, 1))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select the top N sellers for visualization (e.g., top 5)
top_sellers = df1['seller'].value_counts().head(20).index

# Filter data for top sellers
top_sellers_data = df1[df1['seller'].isin(top_sellers)]

# Box plot or violin plot for actual prices by seller
plt.figure(figsize=(14, 8))
sns.barplot(x='seller', y='actual_price', data=top_sellers_data)
plt.xticks(rotation=45)
plt.title('Actual Prices by Top Sellers')
plt.xlabel('Seller')
plt.ylabel('Actual Price')
plt.show()

# %%
# Distribution of Ratings
plt.figure(figsize=(30, 10))
sns.countplot(x='average_rating', data=df1)
plt.title('Distribution of Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Count')
plt.show()

# %%
#Average Rating vs. Category (Bar Plot)
plt.figure(figsize=(14, 8))
sns.barplot(x='category', y='average_rating', data=df1)
plt.title('Average Rating by Category')
plt.xlabel('Category')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
# Select the top 25 brands for visualization
top_brands = df1['brand'].value_counts().head(25).index

# Filter data for top brands
top_brands_data = df1[df1['brand'].isin(top_brands)]

# Box plot of average rating by the top 25 brands
plt.figure(figsize=(14, 8))
sns.barplot(x='brand', y='average_rating', data=top_brands_data, order=top_brands)
plt.title('Average Rating by Top 25 Brands')
plt.xlabel('Brand')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
# Violin plot of average rating by sub-category
plt.figure(figsize=(30, 10))
sns.barplot(x='sub_category', y='average_rating', data=df1)
plt.title('Average Rating by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
# Select the top 20 sellers for visualization
top_sellers = df1['seller'].value_counts().head(20).index

# Filter data for top sellers
top_sellers_data = df1[df1['seller'].isin(top_sellers)]

# Box plot of average rating by the top 20 sellers
plt.figure(figsize=(14, 8))
sns.barplot(x='seller', y='average_rating', data=top_sellers_data, order=top_sellers)
plt.title('Average Rating by Top 20 Sellers')
plt.xlabel('Seller')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
# Select relevant columns for correlation analysis
correlation_columns = df1[['actual_price', 'average_rating']]

# Calculate correlation matrix
correlation_matrix = correlation_columns.corr()

# Plot correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
df1

# %%
df1.to_csv("processeddata.csv", index=False)

# %%
#Text Analysis 
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

# Text preprocessing function
def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

# Apply text preprocessing to the 'description' column
df['processed_description'] = df['description'].fillna('').apply(preprocess_text)

# %%
from wordcloud import WordCloud

# Create a Word Cloud for processed descriptions
wordcloud = WordCloud(width=800, height=400, max_words=100, background_color='white').generate(' '.join(df['processed_description']))

# Plot the Word Cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Processed Descriptions')
plt.axis('off')
plt.show()

# %%
# Explore popular product categories
plt.figure(figsize=(12, 6))
sns.countplot(x='category', data=df1, order=df1['category'].value_counts().index)
plt.title('Distribution of Products by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Select the top 20 brands for visualization
top_brands = df1['brand'].value_counts().head(20).index

# Filter data for top brands
top_brands_data = df1[df1['brand'].isin(top_brands)]

# Explore distribution of products by the top 20 brands
plt.figure(figsize=(12, 6))
sns.countplot(x='brand', data=top_brands_data, order=top_brands)
plt.title('Distribution of Products by Top 20 Brands')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution of actual prices and selling prices
plt.figure(figsize=(12, 6))
sns.histplot(df1['actual_price'], bins=30, kde=True, label='Actual Price')
sns.histplot(df1['selling_price'], bins=30, kde=True, label='Selling Price')
plt.title('Distribution of Actual and Selling Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Average discount percentages
df1['discount_percentage'] = (df1['actual_price'].astype(float) - df1['selling_price'].astype(float)) / df1['actual_price'].astype(float) * 100
average_discount = df1['discount_percentage'].mean()
print(f'Average Discount Percentage: {average_discount:.2f}%')

# Explore discount patterns by category
plt.figure(figsize=(12, 6))
sns.barplot(x='category', y='discount_percentage', data=df1)
plt.title('Discount Percentage by Category')
plt.xlabel('Category')
plt.ylabel('Discount Percentage')
plt.xticks(rotation=45)
plt.show()

# Select the top 20 brands for visualization
top_brands = df1['brand'].value_counts().head(20).index

# Filter data for top brands
top_brands_data = df1[df1['brand'].isin(top_brands)]

# Explore discount patterns by the top 20 brands
plt.figure(figsize=(12, 6))
sns.barplot(x='brand', y='discount_percentage', data=top_brands_data, order=top_brands)
plt.title('Discount Percentage by Top 20 Brands')
plt.xlabel('Brand')
plt.ylabel('Discount Percentage')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Rajasekar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rajasekar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Average Discount Percentage: 50.70%

# %%
# Select the top 20 sellers for visualization
top_sellers = df1['seller'].value_counts().head(20).index

# Filter data for top 20 sellers
top_sellers_data = df1[df1['seller'].isin(top_sellers)]

# Explore distribution of products by the top 10 sellers
plt.figure(figsize=(22, 6))
sns.countplot(x='seller', data=top_sellers_data, order=top_sellers_data['seller'].value_counts().index)
plt.title('Distribution of Products by Top 20 Sellers')
plt.xlabel('Seller')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Explore average ratings by the top 10 sellers
plt.figure(figsize=(12, 6))
sns.barplot(x='seller', y='average_rating', data=top_sellers_data, order=top_sellers_data.groupby('seller')['average_rating'].median().sort_values().index)
plt.title('Average Rating by Top 20 Sellers')
plt.xlabel('Seller')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution of average ratings
plt.figure(figsize=(8, 5))
sns.histplot(df1['average_rating'], bins=30, kde=True)
plt.title('Distribution of Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.show()

# Identify top-rated products
top_rated_products = df1.nlargest(10, 'average_rating')[['title', 'average_rating']]
print('Top Rated Products:')
print(top_rated_products)
# Out:
# C:\Users\Rajasekar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Top Rated Products:
#                                               title  average_rating
# 419                      Solid Men Red Chino Shorts             5.0
# 425                  Printed Men Boxer  (Pack of 1)             5.0
# 451                  Printed Men Boxer  (Pack of 1)             5.0
# 464            Printed Men Round Neck White T-Shirt             5.0
# 790           Men Kurta and Pyjama Set Cotton Blend             5.0
# 804           Men Kurta and Pyjama Set Cotton Blend             5.0
# 1204  Color Block Men Round Neck Multicolor T-Shirt             5.0
# 1977             Sleeveless Solid Men Casual Jacket             5.0
# 2065              Self Design Men Black Track Pants             5.0
# ...

# %%
# Select the top 20 sellers based on the number of products they have
top_sellers = df1['seller'].value_counts().head(20).index

# Filter data for the top 20 sellers
top_sellers_data = df1[df1['seller'].isin(top_sellers)]
# Explore distribution of out-of-stock products by the top 20 sellers
plt.figure(figsize=(12, 6))
sns.countplot(x='seller', data=top_sellers_data[top_sellers_data['out_of_stock']], order=top_sellers_data['seller'].value_counts().index)
plt.title('Distribution of Out-of-Stock Products by Top 20 Sellers')
plt.xlabel('Seller')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Calculate the in-stock and out-of-stock percentage by the top 20 sellers
stock_percentage_top_sellers = top_sellers_data.groupby('seller')['out_of_stock'].mean() * 100

# Visualize the percentage of out-of-stock products by the top 20 sellers
plt.figure(figsize=(12, 6))
sns.barplot(x=stock_percentage_top_sellers.index, y=stock_percentage_top_sellers.values)
plt.title('Percentage of Out-of-Stock Products by Top 20 Sellers')
plt.xlabel('Seller')
plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize the relationship between stock and average ratings
plt.figure(figsize=(12, 6))
sns.boxplot(x='out_of_stock', y='average_rating', data=df1)
plt.title('Stock vs. Average Ratings')
plt.xlabel('Out-of-Stock (1) / In-Stock (0)')
plt.ylabel('Average Rating')
plt.show()

# %%
# Visualize the relationship between stock and discount percentages
plt.figure(figsize=(12, 6))
sns.boxplot(x='out_of_stock', y='discount_percentage', data=df1)
plt.title('Stock vs. Discount Percentages')
plt.xlabel('Out-of-Stock (1) / In-Stock (0)')
plt.ylabel('Discount Percentage')
plt.show()

# %%
# Top 20 brands
top_20_brands = df1.groupby('brand')['discount_percentage'].mean().nlargest(20)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x=top_20_brands.index, y=top_20_brands.values)
plt.title('Top 20 Brands with Highest Average Discounts')
plt.xlabel('Brand')
plt.ylabel('Average Discount Percentage')
plt.xticks(rotation=45)
plt.show()

# %%
# Group by category and calculate average discount
discounts_by_category = df1.groupby('category')['discount_percentage'].mean().sort_values(ascending=False)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x=discounts_by_category.index, y=discounts_by_category.values)
plt.title('Average Discounts by Category')
plt.xlabel('Category')
plt.ylabel('Average Discount Percentage')
plt.xticks(rotation=45)
plt.show()

# %%
# Top 20 sellers
top_20_sellers = df1.groupby('seller')['discount_percentage'].mean().nlargest(20)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x=top_20_sellers.index, y=top_20_sellers.values)
plt.title('Top 20 Sellers with Highest Average Discounts')
plt.xlabel('Seller')
plt.ylabel('Average Discount Percentage')
plt.xticks(rotation=45)
plt.show()
